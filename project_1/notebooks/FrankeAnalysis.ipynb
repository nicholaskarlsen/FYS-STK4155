# %%
import sys
sys.path.insert(0,"../src/")

import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as skl
from mpl_toolkits.mplot3d import Axes3D
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import linear_regression
import utils
import stat_tools

from FrankeFunction import *

# %%
n = 1000 # Number of data points
noise_scale = 0.2

# Generate data
x = np.random.uniform(0, 1, n)
y = np.random.uniform(0, 1, n)
z = FrankeFunction(x, y)
z_noisy = z + noise_scale*np.random.normal(0,1,len(z))

# %%
# Define some useful variables
max_degree = 20
n_lambdas = 30
n_bootstraps = 50
k_folds = 5
lambdas = np.logspace(-3,0,n_lambdas)
subset_lambdas = lambdas[::5]

# %% [markdown]
# # Ordinary Least Squares

# %%
#from franke_analysis import *

# %%
degrees = np.arange(max_degree)

plt.semilogy(degrees[0:5], mse_ols_train[0:5], "o--", label = "OLS TRAIN")
plt.semilogy(degrees[0:5], mse_ols_test[0:5], "o--", label = "OLS TEST")
plt.legend()
plt.show()

# %%
plt.semilogy(degrees, ols_boot_mse,"o--",label="MSE")
plt.semilogy(degrees, ols_boot_bias,"o--", label="BIAS")
plt.semilogy(degrees, ols_boot_variance,"o--", label="Variance")
plt.legend()
plt.show()
