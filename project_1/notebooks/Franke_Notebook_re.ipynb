# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.linear_model as skl
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import sys
sys.path.insert(0,"../src_rewrite/")

from FrankeFunction import FrankeFunction
from linear_regression import *
from bootstrap import *
from cross_validation import *
from stat_tools import *
from main import *
import utils
import unit_tests

utils.plot_settings()

FIGPATH = "../figs/"

# %%
# Make sure things are working as expected
unit_tests.OLS_unit_test()
unit_tests.OLS_SVD_unit_test()
unit_tests.Ridge_unit_test()

# %% [markdown]
# ## Part a): Ordinary Least Square (OLS) on the Franke function
#
# - Play around with the franke funtion both with & without noise!
# - Perform OLS up to 5th order
# - Compute R2
# - Compute MSE
# - Find confidence interval of beta

# %%
# Generate test data
n = 300 # Number of data points

x_dat = np.random.uniform(0, 1, n)
y_dat = np.random.uniform(0, 1, n)
z_dat = FrankeFunction(x_dat, y_dat)

# Set up the scaler
scaler = StandardScaler()

print()

# %%
# Wrap the analysis in a function to duplicate for Clean & Noisy data
def p1_analysis(x, y, z, degrees):
    
    mse = pd.DataFrame(columns=["train", "test"], index = degrees)
    r2 = pd.DataFrame(columns=["train", "test"], index = degrees)
    
    # Very hacky way of determining the maximum number of terms of the polynomials
    betas = np.zeros([len(degrees), len(utils.polynomial_form(degrees[-1]))])
    var_betas = np.zeros([len(degrees), len(utils.polynomial_form(degrees[-1]))])

    #var_b = pd.DataFrame(indices=degrees)
    
    for i, deg in enumerate(degrees):
        X = design_matrix(x, y, deg)
        # Split data, but don't shuffle. OK since data is already randomly sampled! 
        # Fasilitates a direct comparrison of the clean & Noisy data
        X_train, X_test, z_train, z_test = train_test_split(X, z, test_size = 0.2, shuffle=False)
        # Normalize data sets
        X_train = scaler.fit_transform(X_train)
        X_train[:, 0] = np.ones(X_train.shape[0])
        X_test = scaler.fit_transform(X_test)
        X_test[:, 0] = np.ones(X_test.shape[0])

        beta = OLS_SVD(X_train, z_train)
    
        mse["train"][i] = MSE(z_train, X_train @ beta)
        mse["test"][i] = MSE(z_test, X_test @ beta)
        r2["train"][i] = R2(z_train, X_train @ beta)
        r2["test"][i] = R2(z_test, X_test @ beta)
        
        betas[i, 0:len(beta)] = beta
        var_betas[i, 0:len(beta)] = var_beta(X_train, z_train)

    return mse, r2, betas, var_betas

# %%
degrees = np.arange(0, 6) # Degrees of the polynom

# Generate data
MSE_clean, R2_clean, betas_clean, var_betas_clean = p1_analysis(x_dat, y_dat, z_dat, degrees)

plt.figure(figsize=(5,8))
plt.tight_layout()
# Plot MSE
plt.subplot(211)
plt.semilogy(degrees, MSE_clean["train"],"o--", label = "Training data")
plt.semilogy(degrees, MSE_clean["test"],"o--", label = "Test data")
plt.xlabel("Model Complexity")
plt.ylabel("MSE")
plt.legend()
# Plot R2
plt.subplot(212)
plt.plot(degrees, R2_clean["train"],"o--", label = "Training data")
plt.plot(degrees, R2_clean["test"],"o--", label = "Test data")
plt.xlabel("Model Complexity")
plt.ylabel("R2")
plt.ylim([0,1])
plt.legend()

# %%
plt.figure(figsize=(20, 10))
plt.matshow((np.log10(2 * np.sqrt(var_betas_clean))))
plt.ylabel("Complexity")
plt.xlabel("$\\beta_i$")
plt.colorbar()
plt.savefig("test.pdf")
# Out:
# <ipython-input-6-90dd0405103c>:2: RuntimeWarning: divide by zero encountered in log10
#   plt.matshow((np.log10(2 * np.sqrt(var_betas_clean))))

# %%
utils.polynomial_form(5)
# Out:
# ['$\\beta_0$',
#  '$\\beta_1 x^1 y^0$',
#  '$\\beta_2 x^0 y^1$',
#  '$\\beta_3 x^2 y^0$',
#  '$\\beta_4 x^1 y^1$',
#  '$\\beta_5 x^0 y^2$',
#  '$\\beta_6 x^3 y^0$',
#  '$\\beta_7 x^2 y^1$',
#  '$\\beta_8 x^1 y^2$',
#  '$\\beta_9 x^0 y^3$',
#  '$\\beta_10 x^4 y^0$',
#  '$\\beta_11 x^3 y^1$',
#  '$\\beta_12 x^2 y^2$',
#  '$\\beta_13 x^1 y^3$',
#  '$\\beta_14 x^0 y^4$',
#  '$\\beta_15 x^5 y^0$',
#  '$\\beta_16 x^4 y^1$',
#  '$\\beta_17 x^3 y^2$',
#  '$\\beta_18 x^2 y^3$',
#  '$\\beta_19 x^1 y^4$',
#  '$\\beta_20 x^0 y^5$']

# %% [markdown]
# How does the model respond to noise?

# %%
noises = np.linspace(0, .5, 6)
degrees = np.arange(0, 6)

plt.figure(figsize=[4, 5])

for noise in noises:
    # Generate a new noisy dataset
    z_dat_noisy = z_dat + np.random.normal(0, 1, n) * noise
    MSE_noisy, R2_noisy, _, _ = p1_analysis(x_dat, y_dat, z_dat_noisy,degrees)
    
    plt.plot(degrees, R2_noisy["test"], "o--")
    plt.annotate("$\delta=$ %.2f" % noise, [degrees[-1] + .3,R2_noisy["test"].iloc[-1]])

plt.xlim([0, degrees[-1] + 1.5])
plt.axhline([1],color="black", ls="--", lw=0.75)
plt.xlabel("Complexity")
plt.ylabel("R2")
plt.plot()
# Out:
# []

# %%
# Add noise to z_dat going forward.
#z_dat *= np.random.normal(0, 1, n) * 0.2

# %% [markdown]
# ## Part b): Bias-variance trade-off and resamplng techniques
# - Replicate Fig 2.11 from Hastie et al using bootstrap
# - Bias variance analysis

# %%
# Reproduce 2.11 in Hastie
degrees = np.arange(1, 26)
N_bootstraps = 100
OLS_BS_MSE, OLS_BS_BIAS2, OLS_BS_VAR = bootstrap_analysis(x_dat, y_dat, z_dat, degrees, N_bootstraps)

plt.figure(figsize=(4,3))
plt.semilogy(degrees, OLS_BS_MSE,"o--")
plt.xlabel("Model Complexity")
plt.ylabel("MSE")
plt.title("OLS Bootstrap")
plt.tight_layout()
plt.savefig(FIGPATH + "OLS_MSE_Bootstrap_Hastie_211.pdf")

# %%
# Bias-Variance Figure

plt.figure(figsize=(5,5))
plt.semilogy(degrees, OLS_BS_MSE,"o--", label = "MSE", color="gray")
plt.semilogy(degrees, OLS_BS_VAR,"--", label = "Var", color="red")
plt.semilogy(degrees, OLS_BS_BIAS2 ,"--", label = "Bias$^2$", color="blue")
plt.xlabel("Model Complexity")
plt.ylabel("MSE")
plt.title("OLS Bias-Variance")
plt.legend(loc="best")
plt.tight_layout()

# %% [markdown]
# ## Part c) Cross-validation as resampling techniques, adding more complexity
# - Do cross validation on the dataset. Compare MSE with bootstrap

# %%
degrees = np.arange(1, 20)
OLS_MSE_CV = cv_analysis(x_dat, y_dat, z_dat, degrees, k=5)

# %%
plt.figure(figsize=(8,4))
plt.semilogy(degrees, OLS_MSE_CV,"o--", label = "Test data")
plt.xlabel("Model Complexity")
plt.ylabel("MSE")
plt.title("Cross-Validation")
plt.legend(loc="lower left")

# %% [markdown]
# ## Part d): Ridge Regression on the Franke function with resampling
# - Do same analysis, but with Ridge regression

# %%
lambdas = np.logspace(-3, 0, 30)
degrees = np.arange(1, 20)

Ridge_BS_MSE = np.empty((lambdas.size, degrees.size))
Ridge_BS_BIAS2 = np.empty((lambdas.size, degrees.size))
Ridge_BS_VAR = np.empty((lambdas.size, degrees.size))

Ridge_CV_MSE = np.empty((lambdas.size, degrees.size))

for i in range(lambdas.size):    
    N_bootstraps = 50
    # Compute CV
    Ridge_CV_MSE[i, :] = cv_analysis(x_dat, y_dat, z_dat, degrees, k=5, regression= lambda X, z : linear_regression.Ridge(X, z, lamb = lambdas[i]))    
    # Compute MSE
    Ridge_BS_MSE[i, :], Ridge_BS_BIAS2[i, :], Ridge_BS_VAR[i, :] = bootstrap_analysis(x_dat, y_dat, z_dat, degrees, N_bootstraps, 
                                                                                      regression = lambda X, z : linear_regression.Ridge(X, z, lamb = lambdas[i]))

# %%
for i in range(lambdas.size):
    plt.semilogy(degrees, Ridge_CV_MSE[i, :], alpha = 0.4, color="gray")
    
plt.title("Ridge $k=5$ fold cross validation")
# Out:
# Text(0.5, 1.0, 'Ridge $k=5$ fold cross validation')

# %%
plt.figure(figsize=(15, 4))

plt.subplot(121)
for i in range(lambdas.size):
    plt.semilogy(degrees, Ridge_BS_MSE[i, :], alpha=0.4, color="gray")
plt.title("Ridge Bootstrap")
    
plt.subplot(122)
for i in range(lambdas.size):
    plt.semilogy(degrees, Ridge_BS_VAR[i, :], alpha=0.4, color="red")
    plt.semilogy(degrees, Ridge_BS_BIAS2[i, :], alpha=0.4, color="blue")

    
plt.tight_layout()

# %%
plt.matshow(Ridge_BS_MSE)
plt.xlabel("$\\lambda$")
plt.ylabel("Complexity")
plt.colorbar()

# %% [markdown]
# ## Part e): Lasso Regression on the Franke function with resampling
# - Do Same analysis, but with Lasso Regression

# %%
lambdas = np.logspace(-3, 0, 30)
degrees = np.arange(1, 20)

LASSO_BS_MSE = np.empty((lambdas.size, degrees.size))
LASSO_BS_BIAS2 = np.empty((lambdas.size, degrees.size))
LASSO_BS_VAR = np.empty((lambdas.size, degrees.size))
LASSO_CV_MSE = np.empty((lambdas.size, degrees.size))

for i in range(lambdas.size):    
    N_bootstraps = 50
    LASSO_CV_MSE[i, :] = cv_analysis(x_dat, y_dat, z_dat, degrees, k=5, regression = "LASSO", lambd = lambdas[i])  
    LASSO_BS_MSE[i, :], LASSO_BS_BIAS2[i, :], LASSO_BS_VAR[i, :] = bootstrap_analysis(x_dat, y_dat, z_dat, degrees, N_bootstraps, 
                                                                                      regression = "LASSO", lambd=lambdas[i])
# Out:
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.042236831236299954, tolerance: 0.0048266715263963625
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006935302408364485, tolerance: 0.005350696934303861
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016002906358202118, tolerance: 0.005300910326978294
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04174664549077334, tolerance: 0.005325861994033776
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.019454352940993402, tolerance: 0.00480202084802544
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.011546017741164594, tolerance: 0.005576532775202614
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023738701551286434, tolerance: 0.005195249478520429
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.018875455934278307, tolerance: 0.005041187715352942
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006852222957192122, tolerance: 0.005264236664619592
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010198566447768176, tolerance: 0.005058306628720128
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00900086738146233, tolerance: 0.005149210732856558
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.015921995374653664, tolerance: 0.005352014408201349
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010588681303198122, tolerance: 0.0050547148380016395
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.015426966653900198, tolerance: 0.0054126316873231
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03151979266860194, tolerance: 0.005496672764400819
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017082372104105126, tolerance: 0.004973908893670291
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.016482672146572286, tolerance: 0.0050029246277393516
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.025881232616692174, tolerance: 0.005743824493797781
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.031226215355807385, tolerance: 0.0053423127256603566
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.013293063775290825, tolerance: 0.004938700494086829
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.030753816972193038, tolerance: 0.00516628972111493
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017597047018126144, tolerance: 0.004749725376475304
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.022394255146391373, tolerance: 0.004953788640986829
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03611532721112676, tolerance: 0.0052539504303705815
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023900359616493505, tolerance: 0.005222780887611707
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.017668476456738302, tolerance: 0.005337634861136817
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.039227947655806616, tolerance: 0.005172697991029266
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0164090934440122, tolerance: 0.005515874387661167
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.010109643802986623, tolerance: 0.005019673395499524
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03424560276091748, tolerance: 0.00499086005092685
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.01736545593534622, tolerance: 0.005182208180188655
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.032925013173171536, tolerance: 0.005232236796859007
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03241957783536886, tolerance: 0.0050768403881080336
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02498147205814405, tolerance: 0.005218035133110345
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.023612622289910012, tolerance: 0.005494765190210475
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.031007228207521775, tolerance: 0.004881094486418704
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03299916851517226, tolerance: 0.005270117613287643
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.029833784973345656, tolerance: 0.005286154609768617
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.035175702081449156, tolerance: 0.004983386044017796
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0492479968433841, tolerance: 0.0052394183128109005
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.04510246305666166, tolerance: 0.005357100337580875
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0267225405373841, tolerance: 0.005074793506957014
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.057182385373078404, tolerance: 0.005179214442401259
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.02131953918458862, tolerance: 0.005355800031355088
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.048542501049453124, tolerance: 0.005429897958347442
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.03316352574358605, tolerance: 0.0051257288126511725
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008110882384251283, tolerance: 0.005218104053974735
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008761041746874199, tolerance: 0.004739906846706816
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006497433098402894, tolerance: 0.005539226956719685
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005428271778221028, tolerance: 0.004837154826253226
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0058892483810577545, tolerance: 0.0049050581466022454
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006033127708701347, tolerance: 0.004576330571557162
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00607697002862273, tolerance: 0.0056200955977659135
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005758577559530131, tolerance: 0.004943126417410229
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006448231039148489, tolerance: 0.0055369801056460105
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008608918442830404, tolerance: 0.006029616566260846
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005574716678129921, tolerance: 0.005552246220225243
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006182237690782522, tolerance: 0.005520534017829387
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005837126322477015, tolerance: 0.004742954266868199
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00590478111310766, tolerance: 0.00458237413687554
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00592921506909061, tolerance: 0.005175175271340783
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007118962206901891, tolerance: 0.005609060199432098
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008009498066530174, tolerance: 0.005598062584304954
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00563850996252846, tolerance: 0.0051283383951749315
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006577582522522274, tolerance: 0.004919691770806247
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008135461558598678, tolerance: 0.005604218717682166
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007945005916586645, tolerance: 0.005114482675099088
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005459629487712281, tolerance: 0.004783424325211789
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.009660298597442996, tolerance: 0.005289893047213805
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00800205291373235, tolerance: 0.005613280059887895
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0057865243012873435, tolerance: 0.004636130965986034
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006652348801452934, tolerance: 0.005835692305917262
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005407221413156638, tolerance: 0.004605936062010847
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005862605497811035, tolerance: 0.004694400279659034
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0047761811451492164, tolerance: 0.00454693567885568
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00583415290936351, tolerance: 0.004820689775818114
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.008659355383359824, tolerance: 0.006093691100886949
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004299259766156638, tolerance: 0.004288840031350258
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.004796896752405022, tolerance: 0.004656327681438348
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.007209721423977911, tolerance: 0.005285810665524154
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005846423323545125, tolerance: 0.005688477131253531
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.005375208906767792, tolerance: 0.005276985693149995
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.006055204847960738, tolerance: 0.005116474765139569
#   model = cd_fast.enet_coordinate_descent(
# /home/nick/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.00593713981755517, tolerance: 0.005191026904998394
#   model = cd_fast.enet_coordinate_descent(

# %%
for i in range(lambdas.size):
    plt.semilogy(degrees, LASSO_CV_MSE[i, :], alpha = 0.4, color="gray")

# %%
plt.figure(figsize=(15, 4))

plt.subplot(121)
for i in range(lambdas.size):
    plt.semilogy(degrees, LASSO_BS_MSE[i, :], alpha=0.4, color="gray")
    
plt.xlabel("Complexity")
plt.ylabel("MSE")
    
plt.subplot(122)
for i in range(lambdas.size):
    plt.semilogy(degrees, LASSO_BS_VAR[i, :], alpha=0.4, color="red")
    plt.semilogy(degrees, LASSO_BS_BIAS2[i, :], alpha=0.4, color="blue")
    
    
plt.tight_layout()

# %% [markdown]
# # Problem 1f)
# - Download real data!

# %% [markdown]
# # Problem 1d)
# = Analyse real data using wisdom gained from Franke Function!

# %%
def k_fold_split(X, z, k_folds = 5):
    perm = np.random.permutation(len(z))
    perm = np.split(perm, k_folds)
    return perm

X =  np.ones([5, 5])
z = np.ones([5])
for i in range(5):
    X[i] *= i
    z[i] *= i
