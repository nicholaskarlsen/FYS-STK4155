# %%
using Plots; pgfplots()
using LaTeXStrings

# %%
x = -7.5:0.1:7.5
f(x) = 1 / (1 + exp(-x))

plot(size=(300, 200).*0.75, grid=:off, 
    xlabel=L"x", ylabel=L"\frac{1}{1 + e^{-x}}"
)
plot!(x, f.(x), label="", color="black")
savefig("../figs/logistic.tex")
plot!()
