# %% [markdown]
# # Solving the Heat Equation with Neural Networks

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn.functional as F
from torch.autograd.functional import hessian, jacobian
from torchviz import make_dot

plt.rcParams.update({
        "text.usetex": True,
        "font.family": "serif",
})

FIGPATH = "../figs/"
FIGSIZE = (4, 3)

sys.path.insert(0, "../src")
from utils import minibatch, heat_eq_analytic

dtype = torch.float
#device = torch.device("cuda:0")
device = torch.device("cpu")

#torch.autograd.set_detect_anomaly(True)

# %%
def g_trial(x, t, N):
    return (1 - t) * torch.sin(np.pi * x) + x * (1 - x) * t * N

#@torch.jit.script
def ode_loss(input_data, output_data):
    loss = 0
    
    for i in range(input_data.size(0)):
        Jx, Jt, Jn = jacobian(g_trial, (input_data[i,0], input_data[i,1], output_data[i]),create_graph=True)
        Hx, Ht, Hn = hessian(g_trial, (input_data[i,0], input_data[i,1], output_data[i]),create_graph=True)
        loss = loss + (Jt - Hx[0]).pow(2)
    
    return loss / input_data.size(0)

def g_trial_np(x, t, N):
    return (1 - t) * np.sin(np.pi * x) + x * (1 - x) * t * N

def plot_pde(model, grid_size=100, fn = "tmp"):
    # Set up plotting data
    x = np.linspace(0,1,grid_size, dtype=np.float)
    t = np.linspace(0,1,grid_size, dtype=np.float)
    x, t = np.meshgrid(x, t) 
    x_flat = x.flatten()
    t_flat = t.flatten()
    X = np.concatenate((x_flat.reshape(-1,1), t_flat.reshape(-1, 1)), axis=1)

    # Convert to pytorch tensors
    xp = torch.from_numpy(X)
    xp = xp.to(dtype).to(device)
    
    # Evaluate model
    model.eval()    
    N_pred = model(xp)
    N_pred = N_pred.detach().numpy()
    N_pred = N_pred.reshape(grid_size, grid_size)

    g = g_trial_np(x, t, N_pred)

    fig, ax = plt.subplots(figsize=FIGSIZE)
    #cf = ax.pcolormesh(x, t, g, cmap=plt.get_cmap("inferno"))
    cf = ax.pcolormesh(x, t, g, cmap=plt.get_cmap("jet"))
    fig.colorbar(cf, ax=ax)
    ax.set_xlabel("$x$")
    ax.set_ylabel("$t$")
    
    plt.savefig(FIGPATH + fn + ".pdf")
    
    return
    
def plot_error(model, x, t, fn = "tmp"):
    x, t = np.meshgrid(x, t) 
    x_flat = x.flatten()
    t_flat = t.flatten()
    X = np.concatenate((x_flat.reshape(-1,1), t_flat.reshape(-1, 1)), axis=1)
    
    # Convert to pytorch tensors
    xp = torch.from_numpy(X)
    xp = xp.to(dtype).to(device)
    
    # Evaluate model
    model.eval()    
    N_pred = model(xp)
    N_pred = N_pred.detach().numpy()
    N_pred = N_pred.reshape(x.shape)
    
    g_model = g_trial_np(x, t, N_pred)
    g_analytic = heat_eq_analytic(x, t)
    
    #square_error = (g_model - g_analytic)**2
    #MSE = np.mean(square_error.flatten())
    
    relative_error = np.abs(g_model - g_analytic) 
    MAE = np.mean(relative_error.flatten())
    
    fig, ax = plt.subplots(figsize=FIGSIZE)
    #cf = ax.pcolormesh(x, t, g, cmap=plt.get_cmap("inferno"))
    #cf = ax.pcolormesh(x, t, relative_error, cmap=plt.get_cmap("inferno"),label="MSE")
    cf = ax.pcolormesh(x, t, relative_error, cmap=plt.get_cmap("jet"),label="MSE")
    cmap = fig.colorbar(cf, ax=ax)
    cmap.set_label("Absolute Error")
    t = ax.annotate("MAE = %.2e" % MAE, xy=(0.05 * np.amax(x_flat), 0.05 * np.amax(t_flat)))
    t.set_bbox(dict(facecolor='white', alpha=0.5))
    ax.set_xlabel("$x$")
    ax.set_ylabel("$t$")
    
    plt.savefig(FIGPATH + fn + ".pdf")
    
    return

# %%
def generate_trainingdata(x, t):
    x, t = np.meshgrid(x, t) 
    x = x.flatten()
    t = t.flatten()
    X = np.concatenate((x.reshape(-1,1), t.reshape(-1, 1)), axis=1)

    # Convert to pytorch tensors
    x = torch.from_numpy(X)
    x = x.to(dtype).to(device)
    x.requires_grad = True
    return x

# %% [markdown]
# # Training on a 11x11 Grid
#
# We first train a model on an equispaced 10x10 grid using a FFNN with 2 hidden layers with 100 neurons each and the ReLU activation function.

# %%
# Set up data in numpy
grid_size = 11

x = generate_trainingdata(
    x = np.linspace(0,1,grid_size, dtype=np.float),
    t = np.linspace(0,1,grid_size, dtype=np.float)
)

# Shape of the network
num_points, input_dim = x.shape
hidden_neurons = 100
output_dim = 1

# Set up the model
learning_rate = 0.002
N_minibatches = int(num_points / 16)

model_10 = torch.nn.Sequential(
    torch.nn.Linear(input_dim, hidden_neurons),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_neurons, output_dim),
)
optimizer_10 = torch.optim.Adam(model_10.parameters(), lr=learning_rate)

TOT_EPOCHS_10 = 0

loss_arr_tot_10 = np.empty(0, dtype=np.float)
epoch_arr_tot_10 = np.empty(0, dtype=np.float)

# %%
EPOCHS = 10_000

loss_arr_curr_10 = np.empty(EPOCHS, dtype=np.float)
epoch_arr_curr_10 = np.empty(EPOCHS, dtype=np.float)

model_10.train()
for epoch in range(EPOCHS):
    # Pick out a new set of minibatches
    mb = minibatch(num_points, N_minibatches)
    for i in range(N_minibatches):
        N_output = model_10(x[mb[i]])           # Forward pass
        loss = ode_loss(x[mb[i]], N_output)  # Compute loss
        optimizer_10.zero_grad()                # Zero gradients from prev itter
        loss.backward()                      # Backward pass
        optimizer_10.step()                     # Optimize with ADAM
        
    # Compute loss of entire sample
    N_output = model_10(x) 
    loss = ode_loss(x, N_output)
    if epoch % 100 == 0:
        print(f"{TOT_EPOCHS_10 + epoch}: loss = ",loss) 
    loss_arr_curr_10[epoch] = loss
    epoch_arr_curr_10[epoch] = TOT_EPOCHS_10 + epoch

TOT_EPOCHS_10 += EPOCHS    
loss_arr_tot_10 = np.append(loss_arr_tot_10, loss_arr_curr_10)
epoch_arr_tot_10 = np.append(epoch_arr_tot_10, epoch_arr_curr_10)
# Out:
# 0: loss =  tensor([10.1863], grad_fn=<DivBackward0>)
# 100: loss =  tensor([0.0128], grad_fn=<DivBackward0>)
# 200: loss =  tensor([0.0037], grad_fn=<DivBackward0>)
# 300: loss =  tensor([0.0044], grad_fn=<DivBackward0>)
# 400: loss =  tensor([0.0011], grad_fn=<DivBackward0>)
# 500: loss =  tensor([0.0035], grad_fn=<DivBackward0>)
# 600: loss =  tensor([0.0009], grad_fn=<DivBackward0>)
# 700: loss =  tensor([0.0008], grad_fn=<DivBackward0>)
# 800: loss =  tensor([0.0323], grad_fn=<DivBackward0>)
# 900: loss =  tensor([0.0011], grad_fn=<DivBackward0>)
# 1000: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 1100: loss =  tensor([0.0115], grad_fn=<DivBackward0>)
# 1200: loss =  tensor([0.0019], grad_fn=<DivBackward0>)
# 1300: loss =  tensor([0.0010], grad_fn=<DivBackward0>)
# 1400: loss =  tensor([0.0216], grad_fn=<DivBackward0>)
# 1500: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 1600: loss =  tensor([0.0099], grad_fn=<DivBackward0>)
# 1700: loss =  tensor([0.0008], grad_fn=<DivBackward0>)
# 1800: loss =  tensor([0.0039], grad_fn=<DivBackward0>)
# 1900: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 2000: loss =  tensor([0.0056], grad_fn=<DivBackward0>)
# 2100: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 2200: loss =  tensor([0.0225], grad_fn=<DivBackward0>)
# 2300: loss =  tensor([2.5839e-05], grad_fn=<DivBackward0>)
# 2400: loss =  tensor([0.0018], grad_fn=<DivBackward0>)
# 2500: loss =  tensor([0.0020], grad_fn=<DivBackward0>)
# 2600: loss =  tensor([9.8326e-05], grad_fn=<DivBackward0>)
# 2700: loss =  tensor([4.0688e-05], grad_fn=<DivBackward0>)
# 2800: loss =  tensor([0.0014], grad_fn=<DivBackward0>)
# 2900: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 3000: loss =  tensor([0.0019], grad_fn=<DivBackward0>)
# 3100: loss =  tensor([0.0012], grad_fn=<DivBackward0>)
# 3200: loss =  tensor([0.0035], grad_fn=<DivBackward0>)
# 3300: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 3400: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 3500: loss =  tensor([0.0024], grad_fn=<DivBackward0>)
# 3600: loss =  tensor([0.0006], grad_fn=<DivBackward0>)
# 3700: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 3800: loss =  tensor([1.2496e-05], grad_fn=<DivBackward0>)
# 3900: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 4000: loss =  tensor([1.4613e-05], grad_fn=<DivBackward0>)
# 4100: loss =  tensor([0.0137], grad_fn=<DivBackward0>)
# 4200: loss =  tensor([2.9594e-05], grad_fn=<DivBackward0>)
# 4300: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 4400: loss =  tensor([8.8372e-05], grad_fn=<DivBackward0>)
# 4500: loss =  tensor([0.0136], grad_fn=<DivBackward0>)
# 4600: loss =  tensor([0.0031], grad_fn=<DivBackward0>)
# 4700: loss =  tensor([4.0459e-05], grad_fn=<DivBackward0>)
# 4800: loss =  tensor([2.4687e-05], grad_fn=<DivBackward0>)
# 4900: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 5000: loss =  tensor([1.6990e-05], grad_fn=<DivBackward0>)
# 5100: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 5200: loss =  tensor([2.6491e-05], grad_fn=<DivBackward0>)
# 5300: loss =  tensor([1.0555e-05], grad_fn=<DivBackward0>)
# 5400: loss =  tensor([0.0269], grad_fn=<DivBackward0>)
# 5500: loss =  tensor([3.4095e-05], grad_fn=<DivBackward0>)
# 5600: loss =  tensor([2.0195e-05], grad_fn=<DivBackward0>)
# 5700: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 5800: loss =  tensor([5.1712e-05], grad_fn=<DivBackward0>)
# 5900: loss =  tensor([0.0057], grad_fn=<DivBackward0>)
# 6000: loss =  tensor([2.8274e-05], grad_fn=<DivBackward0>)
# 6100: loss =  tensor([2.9943e-05], grad_fn=<DivBackward0>)
# 6200: loss =  tensor([0.0060], grad_fn=<DivBackward0>)
# 6300: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 6400: loss =  tensor([0.0348], grad_fn=<DivBackward0>)
# 6500: loss =  tensor([8.8092e-05], grad_fn=<DivBackward0>)
# 6600: loss =  tensor([3.5627e-05], grad_fn=<DivBackward0>)
# 6700: loss =  tensor([8.8686e-05], grad_fn=<DivBackward0>)
# 6800: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 6900: loss =  tensor([2.0254e-05], grad_fn=<DivBackward0>)
# 7000: loss =  tensor([9.4722e-06], grad_fn=<DivBackward0>)
# 7100: loss =  tensor([2.5380e-05], grad_fn=<DivBackward0>)
# 7200: loss =  tensor([0.0011], grad_fn=<DivBackward0>)
# 7300: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 7400: loss =  tensor([0.0009], grad_fn=<DivBackward0>)
# 7500: loss =  tensor([7.8838e-05], grad_fn=<DivBackward0>)
# 7600: loss =  tensor([0.0025], grad_fn=<DivBackward0>)
# 7700: loss =  tensor([3.9946e-05], grad_fn=<DivBackward0>)
# 7800: loss =  tensor([0.0012], grad_fn=<DivBackward0>)
# 7900: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 8000: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 8100: loss =  tensor([7.3051e-05], grad_fn=<DivBackward0>)
# 8200: loss =  tensor([0.0069], grad_fn=<DivBackward0>)
# 8300: loss =  tensor([0.0020], grad_fn=<DivBackward0>)
# 8400: loss =  tensor([3.0125e-05], grad_fn=<DivBackward0>)
# 8500: loss =  tensor([8.9306e-05], grad_fn=<DivBackward0>)
# 8600: loss =  tensor([0.0060], grad_fn=<DivBackward0>)
# 8700: loss =  tensor([4.4743e-05], grad_fn=<DivBackward0>)
# 8800: loss =  tensor([3.5444e-05], grad_fn=<DivBackward0>)
# 8900: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 9000: loss =  tensor([7.9706e-05], grad_fn=<DivBackward0>)
# 9100: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 9200: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 9300: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 9400: loss =  tensor([1.6081e-05], grad_fn=<DivBackward0>)
# 9500: loss =  tensor([3.4304e-05], grad_fn=<DivBackward0>)
# 9600: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 9700: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 9800: loss =  tensor([6.0198e-05], grad_fn=<DivBackward0>)
# 9900: loss =  tensor([0.0007], grad_fn=<DivBackward0>)

# %%
plt.figure(figsize=FIGSIZE)
plt.semilogy(epoch_arr_tot_10, loss_arr_tot_10)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.savefig(FIGPATH+"PDE_RELU_LOSS.pdf")

# %%
plot_pde(model_10, 11, fn="PDE_RELU_10_10x1000")
plot_pde(model_10, 100, fn="PDE_RELU_10_100x100")
plot_error(model_10, np.linspace(0,1, 100), np.linspace(0,1,100), fn="PDE_RELU_10_ERR")
# Out:
# <ipython-input-45-c83bb75c3924>:41: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cf = ax.pcolormesh(x, t, g, cmap=plt.get_cmap("jet"))
# <ipython-input-45-c83bb75c3924>:78: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cf = ax.pcolormesh(x, t, relative_error, cmap=plt.get_cmap("jet"),label="MSE")

# %%
#make_dot(N_output).render("output_graph", format="pdf")
#make_dot(loss).render("loss_graph", format="pdf")

# %% [markdown]
# # Training on a 100x100 Grid

# %%
# Set up data in numpy
grid_size = 100

x = generate_trainingdata(
    x = np.linspace(0,1,grid_size, dtype=np.float),
    t = np.linspace(0,1,grid_size, dtype=np.float)
)

# %%
# Shape of the network
num_points, input_dim = x.shape
hidden_neurons = 20
output_dim = 1

# Set up the model
learning_rate = 0.002
N_minibatches = int(num_points / 16)

model_100 = torch.nn.Sequential(
    torch.nn.Linear(input_dim, hidden_neurons),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_neurons, output_dim),
)
optimizer_100 = torch.optim.Adam(model_100.parameters(), lr=learning_rate)

TOT_EPOCHS_100 = 0

loss_arr_tot_100 = np.empty(0, dtype=np.float)
epoch_arr_tot_100 = np.empty(0, dtype=np.float)

print("Number of minibatches = ", N_minibatches)
# Out:
# Number of minibatches =  625

# %% [markdown]
# ## Notes
#
# - Gradient changes most rapidly at t ~ 0 to 0.2, so these areas will be most critical for the network to fit correclty. Later, less steeper parts of the function will likely have less of an effect on the cost function

# %%
EPOCHS = 100

loss_arr_curr_100 = np.empty(EPOCHS, dtype=np.float)
epoch_arr_curr_100 = np.empty(EPOCHS, dtype=np.float)

model_100.train()
for epoch in range(EPOCHS):
    # Pick out a new set of minibatches
    mb = minibatch(num_points, N_minibatches)
    for i in range(N_minibatches):
        N_output = model_100(x[mb[i]])           # Forward pass
        loss = ode_loss(x[mb[i]], N_output)  # Compute loss
        optimizer_100.zero_grad()                # Zero gradients from prev itter
        loss.backward()                      # Backward pass
        optimizer_100.step()                     # Optimize with ADAM
        
    # Compute loss of entire sample
    N_output = model_100(x) 
    loss = ode_loss(x, N_output)
    print(f"{TOT_EPOCHS_100 + epoch}: loss = ",loss) 
    loss_arr_curr_100[epoch] = loss
    epoch_arr_curr_100[epoch] = TOT_EPOCHS_100 + epoch

TOT_EPOCHS_100 += EPOCHS    
loss_arr_tot_100 = np.append(loss_arr_tot_100, loss_arr_curr_100)
epoch_arr_tot_100 = np.append(epoch_arr_tot_100, epoch_arr_curr_100)

plt.semilogy(epoch_arr_tot_100, loss_arr_tot_100)
plt.ylabel("Loss")
plt.xlabel("Epoch")
# Out:
# 0: loss =  tensor([0.4878], grad_fn=<DivBackward0>)
# 1: loss =  tensor([0.2487], grad_fn=<DivBackward0>)
# 2: loss =  tensor([0.1245], grad_fn=<DivBackward0>)
# 3: loss =  tensor([0.0934], grad_fn=<DivBackward0>)
# 4: loss =  tensor([0.0899], grad_fn=<DivBackward0>)
# 5: loss =  tensor([0.0746], grad_fn=<DivBackward0>)
# 6: loss =  tensor([0.0730], grad_fn=<DivBackward0>)
# 7: loss =  tensor([0.0628], grad_fn=<DivBackward0>)
# 8: loss =  tensor([0.0698], grad_fn=<DivBackward0>)
# 9: loss =  tensor([0.0498], grad_fn=<DivBackward0>)
# 10: loss =  tensor([0.0413], grad_fn=<DivBackward0>)
# 11: loss =  tensor([0.0382], grad_fn=<DivBackward0>)
# 12: loss =  tensor([0.0365], grad_fn=<DivBackward0>)
# 13: loss =  tensor([0.0388], grad_fn=<DivBackward0>)
# 14: loss =  tensor([0.0291], grad_fn=<DivBackward0>)
# 15: loss =  tensor([0.0225], grad_fn=<DivBackward0>)
# 16: loss =  tensor([0.0270], grad_fn=<DivBackward0>)
# 17: loss =  tensor([0.0257], grad_fn=<DivBackward0>)
# 18: loss =  tensor([0.0294], grad_fn=<DivBackward0>)
# 19: loss =  tensor([0.0229], grad_fn=<DivBackward0>)
# 20: loss =  tensor([0.0622], grad_fn=<DivBackward0>)
# 21: loss =  tensor([0.0226], grad_fn=<DivBackward0>)
# 22: loss =  tensor([0.0166], grad_fn=<DivBackward0>)
# 23: loss =  tensor([0.0166], grad_fn=<DivBackward0>)
# 24: loss =  tensor([0.0136], grad_fn=<DivBackward0>)
# 25: loss =  tensor([0.0196], grad_fn=<DivBackward0>)
# 26: loss =  tensor([0.0189], grad_fn=<DivBackward0>)
# 27: loss =  tensor([0.0146], grad_fn=<DivBackward0>)
# 28: loss =  tensor([0.0141], grad_fn=<DivBackward0>)
# 29: loss =  tensor([0.0275], grad_fn=<DivBackward0>)
# 30: loss =  tensor([0.0188], grad_fn=<DivBackward0>)
# 31: loss =  tensor([0.0219], grad_fn=<DivBackward0>)
# 32: loss =  tensor([0.0129], grad_fn=<DivBackward0>)
# 33: loss =  tensor([0.0317], grad_fn=<DivBackward0>)
# 34: loss =  tensor([0.0196], grad_fn=<DivBackward0>)
# 35: loss =  tensor([0.0187], grad_fn=<DivBackward0>)
# 36: loss =  tensor([0.0127], grad_fn=<DivBackward0>)
# 37: loss =  tensor([0.0134], grad_fn=<DivBackward0>)
# 38: loss =  tensor([0.0215], grad_fn=<DivBackward0>)
# 39: loss =  tensor([0.0156], grad_fn=<DivBackward0>)
# 40: loss =  tensor([0.0144], grad_fn=<DivBackward0>)
# 41: loss =  tensor([0.0143], grad_fn=<DivBackward0>)
# 42: loss =  tensor([0.0189], grad_fn=<DivBackward0>)
# 43: loss =  tensor([0.0156], grad_fn=<DivBackward0>)
# 44: loss =  tensor([0.0150], grad_fn=<DivBackward0>)
# 45: loss =  tensor([0.0101], grad_fn=<DivBackward0>)
# 46: loss =  tensor([0.0197], grad_fn=<DivBackward0>)
# 47: loss =  tensor([0.0117], grad_fn=<DivBackward0>)
# 48: loss =  tensor([0.0128], grad_fn=<DivBackward0>)
# 49: loss =  tensor([0.0110], grad_fn=<DivBackward0>)
# 50: loss =  tensor([0.0126], grad_fn=<DivBackward0>)
# 51: loss =  tensor([0.0247], grad_fn=<DivBackward0>)
# 52: loss =  tensor([0.0246], grad_fn=<DivBackward0>)
# 53: loss =  tensor([0.0100], grad_fn=<DivBackward0>)
# 54: loss =  tensor([0.0120], grad_fn=<DivBackward0>)
# 55: loss =  tensor([0.0106], grad_fn=<DivBackward0>)
# 56: loss =  tensor([0.0129], grad_fn=<DivBackward0>)
# 57: loss =  tensor([0.0239], grad_fn=<DivBackward0>)
# 58: loss =  tensor([0.0124], grad_fn=<DivBackward0>)
# 59: loss =  tensor([0.0102], grad_fn=<DivBackward0>)
# 60: loss =  tensor([0.0199], grad_fn=<DivBackward0>)
# 61: loss =  tensor([0.0124], grad_fn=<DivBackward0>)
# 62: loss =  tensor([0.0162], grad_fn=<DivBackward0>)
# 63: loss =  tensor([0.0080], grad_fn=<DivBackward0>)
# 64: loss =  tensor([0.0097], grad_fn=<DivBackward0>)
# 65: loss =  tensor([0.0144], grad_fn=<DivBackward0>)
# 66: loss =  tensor([0.0092], grad_fn=<DivBackward0>)
# 67: loss =  tensor([0.0136], grad_fn=<DivBackward0>)
# 68: loss =  tensor([0.0101], grad_fn=<DivBackward0>)
# 69: loss =  tensor([0.0089], grad_fn=<DivBackward0>)
# 70: loss =  tensor([0.0159], grad_fn=<DivBackward0>)
# 71: loss =  tensor([0.0081], grad_fn=<DivBackward0>)
# 72: loss =  tensor([0.0090], grad_fn=<DivBackward0>)
# 73: loss =  tensor([0.0210], grad_fn=<DivBackward0>)
# 74: loss =  tensor([0.0165], grad_fn=<DivBackward0>)
# 75: loss =  tensor([0.0095], grad_fn=<DivBackward0>)
# 76: loss =  tensor([0.0072], grad_fn=<DivBackward0>)
# 77: loss =  tensor([0.0119], grad_fn=<DivBackward0>)
# 78: loss =  tensor([0.0090], grad_fn=<DivBackward0>)
# 79: loss =  tensor([0.0095], grad_fn=<DivBackward0>)
# 80: loss =  tensor([0.0102], grad_fn=<DivBackward0>)
# 81: loss =  tensor([0.0122], grad_fn=<DivBackward0>)
# 82: loss =  tensor([0.0114], grad_fn=<DivBackward0>)
# 83: loss =  tensor([0.0096], grad_fn=<DivBackward0>)
# 84: loss =  tensor([0.0093], grad_fn=<DivBackward0>)
# 85: loss =  tensor([0.0122], grad_fn=<DivBackward0>)
# 86: loss =  tensor([0.0086], grad_fn=<DivBackward0>)
# 87: loss =  tensor([0.0201], grad_fn=<DivBackward0>)
# 88: loss =  tensor([0.0147], grad_fn=<DivBackward0>)
# 89: loss =  tensor([0.0137], grad_fn=<DivBackward0>)
# 90: loss =  tensor([0.0106], grad_fn=<DivBackward0>)
# 91: loss =  tensor([0.0097], grad_fn=<DivBackward0>)
# 92: loss =  tensor([0.0085], grad_fn=<DivBackward0>)
# 93: loss =  tensor([0.0082], grad_fn=<DivBackward0>)
# 94: loss =  tensor([0.0086], grad_fn=<DivBackward0>)
# 95: loss =  tensor([0.0086], grad_fn=<DivBackward0>)
# 96: loss =  tensor([0.0103], grad_fn=<DivBackward0>)
# 97: loss =  tensor([0.0104], grad_fn=<DivBackward0>)
# 98: loss =  tensor([0.0084], grad_fn=<DivBackward0>)
# 99: loss =  tensor([0.0083], grad_fn=<DivBackward0>)
# Text(0.5, 0, 'Epoch')

# %%
plt.figure(figsize=FIGSIZE)
plt.semilogy(epoch_arr_tot_100, loss_arr_tot_100)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.savefig(FIGPATH+"PDE_RELU_LOSS_100.pdf")

# %%
plot_pde(model=model_100, grid_size=11, fn="PDE_RELU_100_10x10")
plot_pde(model=model_100, grid_size=100, fn="PDE_RELU_100_100x100")
plot_error(model_100, np.linspace(0,1, 100), np.linspace(0,1,100), fn="PDE_RELU_100_ERR")
# Out:
# <ipython-input-45-c83bb75c3924>:41: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cf = ax.pcolormesh(x, t, g, cmap=plt.get_cmap("jet"))
# <ipython-input-45-c83bb75c3924>:78: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cf = ax.pcolormesh(x, t, relative_error, cmap=plt.get_cmap("jet"),label="MSE")

# %% [markdown]
# ## Random sampling

# %%
# Set up data in numpy
grid_size = 11

x = generate_trainingdata(
    x = np.random.uniform(0,1,grid_size),
    t = np.random.uniform(0,1,grid_size)
)

# %%
# Shape of the network
num_points, input_dim = x.shape
hidden_neurons = 100
output_dim = 1

# Set up the model
learning_rate = 0.002
N_minibatches = int(num_points / 16)

model_rand = torch.nn.Sequential(
    torch.nn.Linear(input_dim, hidden_neurons),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_neurons, output_dim),
)
optimizer_rand = torch.optim.Adam(model_rand.parameters(), lr=learning_rate)

TOT_EPOCHS_rand = 0

loss_arr_tot_rand = np.empty(0, dtype=np.float)
epoch_arr_tot_rand = np.empty(0, dtype=np.float)

print("Number of minibatches = ", N_minibatches)
# Out:
# Number of minibatches =  7

# %%
EPOCHS = 10_000

loss_arr_curr_rand = np.empty(EPOCHS, dtype=np.float)
epoch_arr_curr_rand = np.empty(EPOCHS, dtype=np.float)

model_rand.train()
for epoch in range(EPOCHS):
    # Pick out a new set of minibatches
    mb = minibatch(num_points, N_minibatches)
    for i in range(N_minibatches):
        N_output = model_rand(x[mb[i]])      # Forward pass
        loss = ode_loss(x[mb[i]], N_output)  # Compute loss
        optimizer_rand.zero_grad()           # Zero gradients from prev itter
        loss.backward()                      # Backward pass
        optimizer_rand.step()                # Optimize with ADAM
        
    # Compute loss of entire sample
    N_output = model_rand(x) 
    loss = ode_loss(x, N_output)
    if epoch % 100 == 0:
        print(f"{TOT_EPOCHS_rand + epoch}: loss = ",loss) 
    loss_arr_curr_rand[epoch] = loss
    epoch_arr_curr_rand[epoch] = TOT_EPOCHS_rand + epoch

TOT_EPOCHS_rand += EPOCHS    
loss_arr_tot_rand = np.append(loss_arr_tot_rand, loss_arr_curr_rand)
epoch_arr_tot_rand = np.append(epoch_arr_tot_rand, epoch_arr_curr_rand)

plt.semilogy(epoch_arr_tot_rand, loss_arr_tot_rand)
plt.ylabel("Loss")
plt.xlabel("Epoch")
# Out:
# 0: loss =  tensor([16.2920], grad_fn=<DivBackward0>)
# 100: loss =  tensor([0.0090], grad_fn=<DivBackward0>)
# 200: loss =  tensor([0.0069], grad_fn=<DivBackward0>)
# 300: loss =  tensor([0.0044], grad_fn=<DivBackward0>)
# 400: loss =  tensor([0.0050], grad_fn=<DivBackward0>)
# 500: loss =  tensor([0.0023], grad_fn=<DivBackward0>)
# 600: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 700: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 800: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 900: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 1000: loss =  tensor([0.0330], grad_fn=<DivBackward0>)
# 1100: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 1200: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 1300: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 1400: loss =  tensor([0.0012], grad_fn=<DivBackward0>)
# 1500: loss =  tensor([0.0058], grad_fn=<DivBackward0>)
# 1600: loss =  tensor([0.0015], grad_fn=<DivBackward0>)
# 1700: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 1800: loss =  tensor([0.0025], grad_fn=<DivBackward0>)
# 1900: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 2000: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 2100: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 2200: loss =  tensor([0.0028], grad_fn=<DivBackward0>)
# 2300: loss =  tensor([0.0009], grad_fn=<DivBackward0>)
# 2400: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 2500: loss =  tensor([0.0082], grad_fn=<DivBackward0>)
# 2600: loss =  tensor([0.0016], grad_fn=<DivBackward0>)
# 2700: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 2800: loss =  tensor([0.0125], grad_fn=<DivBackward0>)
# 2900: loss =  tensor([6.1724e-05], grad_fn=<DivBackward0>)
# 3000: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 3100: loss =  tensor([0.0011], grad_fn=<DivBackward0>)
# 3200: loss =  tensor([8.9841e-05], grad_fn=<DivBackward0>)
# 3300: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 3400: loss =  tensor([7.9350e-05], grad_fn=<DivBackward0>)
# 3500: loss =  tensor([7.1459e-05], grad_fn=<DivBackward0>)
# 3600: loss =  tensor([0.0007], grad_fn=<DivBackward0>)
# 3700: loss =  tensor([8.6515e-05], grad_fn=<DivBackward0>)
# 3800: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 3900: loss =  tensor([0.0009], grad_fn=<DivBackward0>)
# 4000: loss =  tensor([0.0038], grad_fn=<DivBackward0>)
# 4100: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 4200: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 4300: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 4400: loss =  tensor([0.0028], grad_fn=<DivBackward0>)
# 4500: loss =  tensor([0.0029], grad_fn=<DivBackward0>)
# 4600: loss =  tensor([0.0043], grad_fn=<DivBackward0>)
# 4700: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 4800: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 4900: loss =  tensor([6.6428e-05], grad_fn=<DivBackward0>)
# 5000: loss =  tensor([0.0032], grad_fn=<DivBackward0>)
# 5100: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 5200: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 5300: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 5400: loss =  tensor([0.0021], grad_fn=<DivBackward0>)
# 5500: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 5600: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 5700: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 5800: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 5900: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 6000: loss =  tensor([8.4198e-05], grad_fn=<DivBackward0>)
# 6100: loss =  tensor([4.3530e-05], grad_fn=<DivBackward0>)
# 6200: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 6300: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 6400: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 6500: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 6600: loss =  tensor([4.1529e-05], grad_fn=<DivBackward0>)
# 6700: loss =  tensor([0.0038], grad_fn=<DivBackward0>)
# 6800: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 6900: loss =  tensor([0.0013], grad_fn=<DivBackward0>)
# 7000: loss =  tensor([6.1765e-05], grad_fn=<DivBackward0>)
# 7100: loss =  tensor([5.2946e-05], grad_fn=<DivBackward0>)
# 7200: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 7300: loss =  tensor([0.0017], grad_fn=<DivBackward0>)
# 7400: loss =  tensor([9.3744e-05], grad_fn=<DivBackward0>)
# 7500: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 7600: loss =  tensor([7.3382e-05], grad_fn=<DivBackward0>)
# 7700: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 7800: loss =  tensor([0.0009], grad_fn=<DivBackward0>)
# 7900: loss =  tensor([0.0007], grad_fn=<DivBackward0>)
# 8000: loss =  tensor([7.2502e-05], grad_fn=<DivBackward0>)
# 8100: loss =  tensor([2.9687e-05], grad_fn=<DivBackward0>)
# 8200: loss =  tensor([0.0007], grad_fn=<DivBackward0>)
# 8300: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 8400: loss =  tensor([7.3894e-05], grad_fn=<DivBackward0>)
# 8500: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 8600: loss =  tensor([0.0006], grad_fn=<DivBackward0>)
# 8700: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 8800: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 8900: loss =  tensor([7.7681e-05], grad_fn=<DivBackward0>)
# 9000: loss =  tensor([0.0008], grad_fn=<DivBackward0>)
# 9100: loss =  tensor([5.6105e-05], grad_fn=<DivBackward0>)
# 9200: loss =  tensor([0.0060], grad_fn=<DivBackward0>)
# 9300: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 9400: loss =  tensor([5.2873e-05], grad_fn=<DivBackward0>)
# 9500: loss =  tensor([0.0015], grad_fn=<DivBackward0>)
# 9600: loss =  tensor([0.0011], grad_fn=<DivBackward0>)
# 9700: loss =  tensor([0.0024], grad_fn=<DivBackward0>)
# 9800: loss =  tensor([7.7922e-05], grad_fn=<DivBackward0>)
# 9900: loss =  tensor([8.8365e-05], grad_fn=<DivBackward0>)
# Text(0.5, 0, 'Epoch')

# %%
plt.figure(figsize=FIGSIZE)
plt.semilogy(epoch_arr_tot_rand, loss_arr_tot_rand)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.savefig(FIGPATH+"PDE_RELU_LOSS_RAND.pdf")

# %%
plot_pde(model=model_rand, grid_size=11, fn="PDE_RELU_RAND_10x10")
plot_pde(model=model_rand, grid_size=100, fn="PDE_RELU_RAND_100x100")
plot_error(model_rand, np.linspace(0,1, 100), np.linspace(0,1,100),fn="PDE_RELU_RAND_ERR")
# Out:
# <ipython-input-45-c83bb75c3924>:41: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cf = ax.pcolormesh(x, t, g, cmap=plt.get_cmap("jet"))
# <ipython-input-45-c83bb75c3924>:78: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cf = ax.pcolormesh(x, t, relative_error, cmap=plt.get_cmap("jet"),label="MSE")

# %% [markdown]
# # Testing different activations
# ## Sigmoid

# %%
activation_function = torch.nn.Sigmoid()

# Set up data in numpy
grid_size = 11

x = generate_trainingdata(
    x = np.linspace(0,1,grid_size, dtype=np.float),
    t = np.linspace(0,1,grid_size, dtype=np.float)
)

# Shape of the network
num_points, input_dim = x.shape
hidden_neurons = 100
output_dim = 1

# Set up the model
learning_rate = 0.002
N_minibatches = int(num_points / 16)

model_sigmoid = torch.nn.Sequential(
    torch.nn.Linear(input_dim, hidden_neurons),
    activation_function,
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    activation_function,
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    activation_function,
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    activation_function,
    torch.nn.Linear(hidden_neurons, output_dim),
)
optimizer_sigmoid = torch.optim.Adam(model_sigmoid.parameters(), lr=learning_rate)

TOT_EPOCHS_sigmoid = 0

loss_arr_tot_sigmoid = np.empty(0, dtype=np.float)
epoch_arr_tot_sigmoid = np.empty(0, dtype=np.float)

# %%
EPOCHS = 10_000

loss_arr_curr_sigmoid = np.empty(EPOCHS, dtype=np.float)
epoch_arr_curr_sigmoid = np.empty(EPOCHS, dtype=np.float)

model_sigmoid.train()
for epoch in range(EPOCHS):
    # Pick out a new set of minibatches
    mb = minibatch(num_points, N_minibatches)
    for i in range(N_minibatches):
        N_output = model_sigmoid(x[mb[i]])           # Forward pass
        loss = ode_loss(x[mb[i]], N_output)  # Compute loss
        optimizer_sigmoid.zero_grad()                # Zero gradients from prev itter
        loss.backward()                      # Backward pass
        optimizer_sigmoid.step()                     # Optimize with ADAM
        
    # Compute loss of entire sample
    N_output = model_sigmoid(x) 
    loss = ode_loss(x, N_output)
    if epoch % 100 == 0:
        print(f"{TOT_EPOCHS_sigmoid + epoch}: loss = ",loss) 
    loss_arr_curr_sigmoid[epoch] = loss
    epoch_arr_curr_sigmoid[epoch] = TOT_EPOCHS_sigmoid + epoch

TOT_EPOCHS_sigmoid += EPOCHS    
loss_arr_tot_sigmoid = np.append(loss_arr_tot_sigmoid, loss_arr_curr_sigmoid)
epoch_arr_tot_sigmoid = np.append(epoch_arr_tot_sigmoid, epoch_arr_curr_sigmoid)

plt.semilogy(epoch_arr_tot_sigmoid, loss_arr_tot_sigmoid)
plt.ylabel("Loss")
plt.xlabel("Epoch")
# Out:
# 0: loss =  tensor([10.0149], grad_fn=<DivBackward0>)
# 100: loss =  tensor([2.0278], grad_fn=<DivBackward0>)
# 200: loss =  tensor([1.5893], grad_fn=<DivBackward0>)
# 300: loss =  tensor([1.2502], grad_fn=<DivBackward0>)
# 400: loss =  tensor([1.2316], grad_fn=<DivBackward0>)
# 500: loss =  tensor([1.1392], grad_fn=<DivBackward0>)
# 600: loss =  tensor([0.6408], grad_fn=<DivBackward0>)
# 700: loss =  tensor([0.3120], grad_fn=<DivBackward0>)
# 800: loss =  tensor([0.2448], grad_fn=<DivBackward0>)
# 900: loss =  tensor([0.1791], grad_fn=<DivBackward0>)
# 1000: loss =  tensor([0.1543], grad_fn=<DivBackward0>)
# 1100: loss =  tensor([0.0564], grad_fn=<DivBackward0>)
# 1200: loss =  tensor([0.0516], grad_fn=<DivBackward0>)
# 1300: loss =  tensor([0.0215], grad_fn=<DivBackward0>)
# 1400: loss =  tensor([0.0264], grad_fn=<DivBackward0>)
# 1500: loss =  tensor([0.0106], grad_fn=<DivBackward0>)
# 1600: loss =  tensor([0.0159], grad_fn=<DivBackward0>)
# 1700: loss =  tensor([0.0203], grad_fn=<DivBackward0>)
# 1800: loss =  tensor([0.0493], grad_fn=<DivBackward0>)
# 1900: loss =  tensor([0.0052], grad_fn=<DivBackward0>)
# 2000: loss =  tensor([0.0112], grad_fn=<DivBackward0>)
# 2100: loss =  tensor([0.0028], grad_fn=<DivBackward0>)
# 2200: loss =  tensor([0.0081], grad_fn=<DivBackward0>)
# 2300: loss =  tensor([0.0079], grad_fn=<DivBackward0>)
# 2400: loss =  tensor([0.0023], grad_fn=<DivBackward0>)
# 2500: loss =  tensor([0.0028], grad_fn=<DivBackward0>)
# 2600: loss =  tensor([0.0027], grad_fn=<DivBackward0>)
# 2700: loss =  tensor([0.0006], grad_fn=<DivBackward0>)
# 2800: loss =  tensor([0.0050], grad_fn=<DivBackward0>)
# 2900: loss =  tensor([0.0014], grad_fn=<DivBackward0>)
# 3000: loss =  tensor([0.0031], grad_fn=<DivBackward0>)
# 3100: loss =  tensor([0.0025], grad_fn=<DivBackward0>)
# 3200: loss =  tensor([0.0154], grad_fn=<DivBackward0>)
# 3300: loss =  tensor([0.0017], grad_fn=<DivBackward0>)
# 3400: loss =  tensor([0.0045], grad_fn=<DivBackward0>)
# 3500: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 3600: loss =  tensor([0.0229], grad_fn=<DivBackward0>)
# 3700: loss =  tensor([0.0038], grad_fn=<DivBackward0>)
# 3800: loss =  tensor([0.0020], grad_fn=<DivBackward0>)
# 3900: loss =  tensor([0.0012], grad_fn=<DivBackward0>)
# 4000: loss =  tensor([0.0006], grad_fn=<DivBackward0>)
# 4100: loss =  tensor([0.0035], grad_fn=<DivBackward0>)
# 4200: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 4300: loss =  tensor([0.0018], grad_fn=<DivBackward0>)
# 4400: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 4500: loss =  tensor([0.0015], grad_fn=<DivBackward0>)
# 4600: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 4700: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 4800: loss =  tensor([0.2689], grad_fn=<DivBackward0>)
# 4900: loss =  tensor([0.0093], grad_fn=<DivBackward0>)
# 5000: loss =  tensor([0.0035], grad_fn=<DivBackward0>)
# 5100: loss =  tensor([0.0029], grad_fn=<DivBackward0>)
# 5200: loss =  tensor([0.0007], grad_fn=<DivBackward0>)
# 5300: loss =  tensor([0.0008], grad_fn=<DivBackward0>)
# 5400: loss =  tensor([0.0006], grad_fn=<DivBackward0>)
# 5500: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 5600: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 5700: loss =  tensor([0.0012], grad_fn=<DivBackward0>)
# 5800: loss =  tensor([0.0027], grad_fn=<DivBackward0>)
# 5900: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 6000: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 6100: loss =  tensor([0.0012], grad_fn=<DivBackward0>)
# 6200: loss =  tensor([0.0011], grad_fn=<DivBackward0>)
# 6300: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 6400: loss =  tensor([0.0021], grad_fn=<DivBackward0>)
# 6500: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 6600: loss =  tensor([0.0006], grad_fn=<DivBackward0>)
# 6700: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 6800: loss =  tensor([0.0165], grad_fn=<DivBackward0>)
# 6900: loss =  tensor([0.0056], grad_fn=<DivBackward0>)
# 7000: loss =  tensor([0.0007], grad_fn=<DivBackward0>)
# 7100: loss =  tensor([0.0007], grad_fn=<DivBackward0>)
# 7200: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 7300: loss =  tensor([0.0002], grad_fn=<DivBackward0>)
# 7400: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 7500: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 7600: loss =  tensor([0.0007], grad_fn=<DivBackward0>)
# 7700: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 7800: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 7900: loss =  tensor([0.0017], grad_fn=<DivBackward0>)
# 8000: loss =  tensor([0.0014], grad_fn=<DivBackward0>)
# 8100: loss =  tensor([0.0008], grad_fn=<DivBackward0>)
# 8200: loss =  tensor([0.0021], grad_fn=<DivBackward0>)
# 8300: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 8400: loss =  tensor([0.0050], grad_fn=<DivBackward0>)
# 8500: loss =  tensor([7.4205e-05], grad_fn=<DivBackward0>)
# 8600: loss =  tensor([0.0005], grad_fn=<DivBackward0>)
# 8700: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 8800: loss =  tensor([0.0020], grad_fn=<DivBackward0>)
# 8900: loss =  tensor([0.0015], grad_fn=<DivBackward0>)
# 9000: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 9100: loss =  tensor([9.6181e-05], grad_fn=<DivBackward0>)
# 9200: loss =  tensor([0.0011], grad_fn=<DivBackward0>)
# 9300: loss =  tensor([0.0016], grad_fn=<DivBackward0>)
# 9400: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 9500: loss =  tensor([0.0003], grad_fn=<DivBackward0>)
# 9600: loss =  tensor([0.0001], grad_fn=<DivBackward0>)
# 9700: loss =  tensor([0.0165], grad_fn=<DivBackward0>)
# 9800: loss =  tensor([0.0015], grad_fn=<DivBackward0>)
# 9900: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# Text(0.5, 0, 'Epoch')

# %%
plt.figure(figsize=FIGSIZE)
plt.semilogy(epoch_arr_tot_sigmoid, loss_arr_tot_sigmoid)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.savefig(FIGPATH+"PDE_SIG_LOSS.pdf")

# %%
plot_pde(model=model_sigmoid, grid_size=11, fn="PDE_SIG_10x10")
plot_pde(model=model_sigmoid, grid_size=100, fn="PDE_SIG_100x100")
plot_error(model_sigmoid, np.linspace(0,1, 200), np.linspace(0,1,200), fn="PDE_SIG_ERR")
# Out:
# <ipython-input-45-c83bb75c3924>:41: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cf = ax.pcolormesh(x, t, g, cmap=plt.get_cmap("jet"))
# <ipython-input-45-c83bb75c3924>:78: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cf = ax.pcolormesh(x, t, relative_error, cmap=plt.get_cmap("jet"),label="MSE")

# %% [markdown]
# ## Tanh

# %%
activation_function = torch.nn.Tanh()

# Set up data in numpy
grid_size = 11

x = generate_trainingdata(
    x = np.linspace(0,1,grid_size, dtype=np.float),
    t = np.linspace(0,1,grid_size, dtype=np.float)
)

# Shape of the network
num_points, input_dim = x.shape
hidden_neurons = 100
output_dim = 1

# Set up the model
learning_rate = 0.002
N_minibatches = int(num_points / 16)

model_tanh = torch.nn.Sequential(
    torch.nn.Linear(input_dim, hidden_neurons),
    activation_function,
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    activation_function,
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    activation_function,
    torch.nn.Linear(hidden_neurons, hidden_neurons),
    activation_function,
    torch.nn.Linear(hidden_neurons, output_dim),
)
optimizer_tanh = torch.optim.Adam(model_tanh.parameters(), lr=learning_rate)

TOT_EPOCHS_tanh = 0

loss_arr_tot_tanh = np.empty(0, dtype=np.float)
epoch_arr_tot_tanh = np.empty(0, dtype=np.float)

# %%
EPOCHS = 10_000

loss_arr_curr_tanh = np.empty(EPOCHS, dtype=np.float)
epoch_arr_curr_tanh = np.empty(EPOCHS, dtype=np.float)

model_tanh.train()
for epoch in range(EPOCHS):
    # Pick out a new set of minibatches
    mb = minibatch(num_points, N_minibatches)
    for i in range(N_minibatches):
        N_output = model_tanh(x[mb[i]])           # Forward pass
        loss = ode_loss(x[mb[i]], N_output)  # Compute loss
        optimizer_tanh.zero_grad()                # Zero gradients from prev itter
        loss.backward()                      # Backward pass
        optimizer_tanh.step()                     # Optimize with ADAM
        
    # Compute loss of entire sample
    N_output = model_tanh(x) 
    loss = ode_loss(x, N_output)
    if epoch % 100 == 0:
        print(f"{TOT_EPOCHS_tanh + epoch}: loss = ",loss) 
    loss_arr_curr_tanh[epoch] = loss
    epoch_arr_curr_tanh[epoch] = TOT_EPOCHS_tanh + epoch

TOT_EPOCHS_tanh += EPOCHS    
loss_arr_tot_tanh = np.append(loss_arr_tot_tanh, loss_arr_curr_tanh)
epoch_arr_tot_tanh = np.append(epoch_arr_tot_tanh, epoch_arr_curr_tanh)

plt.semilogy(epoch_arr_tot_tanh, loss_arr_tot_tanh)
plt.ylabel("Loss")
plt.xlabel("Epoch")
# Out:
# 0: loss =  tensor([9.8595], grad_fn=<DivBackward0>)
# 100: loss =  tensor([0.1699], grad_fn=<DivBackward0>)
# 200: loss =  tensor([0.0121], grad_fn=<DivBackward0>)
# 300: loss =  tensor([0.0037], grad_fn=<DivBackward0>)
# 400: loss =  tensor([0.0051], grad_fn=<DivBackward0>)
# 500: loss =  tensor([0.0779], grad_fn=<DivBackward0>)
# 600: loss =  tensor([0.0022], grad_fn=<DivBackward0>)
# 700: loss =  tensor([0.0047], grad_fn=<DivBackward0>)
# 800: loss =  tensor([0.0188], grad_fn=<DivBackward0>)
# 900: loss =  tensor([0.0578], grad_fn=<DivBackward0>)
# 1000: loss =  tensor([0.0047], grad_fn=<DivBackward0>)
# 1100: loss =  tensor([0.0068], grad_fn=<DivBackward0>)
# 1200: loss =  tensor([0.0053], grad_fn=<DivBackward0>)
# 1300: loss =  tensor([0.0038], grad_fn=<DivBackward0>)
# 1400: loss =  tensor([0.0167], grad_fn=<DivBackward0>)
# 1500: loss =  tensor([0.0025], grad_fn=<DivBackward0>)
# 1600: loss =  tensor([0.0058], grad_fn=<DivBackward0>)
# 1700: loss =  tensor([0.1059], grad_fn=<DivBackward0>)
# 1800: loss =  tensor([0.0113], grad_fn=<DivBackward0>)
# 1900: loss =  tensor([0.0026], grad_fn=<DivBackward0>)
# 2000: loss =  tensor([0.0019], grad_fn=<DivBackward0>)
# 2100: loss =  tensor([0.0524], grad_fn=<DivBackward0>)
# 2200: loss =  tensor([0.0010], grad_fn=<DivBackward0>)
# 2300: loss =  tensor([0.0048], grad_fn=<DivBackward0>)
# 2400: loss =  tensor([0.0010], grad_fn=<DivBackward0>)
# 2500: loss =  tensor([0.0010], grad_fn=<DivBackward0>)
# 2600: loss =  tensor([0.0032], grad_fn=<DivBackward0>)
# 2700: loss =  tensor([0.0017], grad_fn=<DivBackward0>)
# 2800: loss =  tensor([0.0067], grad_fn=<DivBackward0>)
# 2900: loss =  tensor([0.0066], grad_fn=<DivBackward0>)
# 3000: loss =  tensor([0.0066], grad_fn=<DivBackward0>)
# 3100: loss =  tensor([0.0088], grad_fn=<DivBackward0>)
# 3200: loss =  tensor([0.0093], grad_fn=<DivBackward0>)
# 3300: loss =  tensor([0.0062], grad_fn=<DivBackward0>)
# 3400: loss =  tensor([0.0026], grad_fn=<DivBackward0>)
# 3500: loss =  tensor([0.0058], grad_fn=<DivBackward0>)
# 3600: loss =  tensor([0.0011], grad_fn=<DivBackward0>)
# 3700: loss =  tensor([0.0033], grad_fn=<DivBackward0>)
# 3800: loss =  tensor([0.0086], grad_fn=<DivBackward0>)
# 3900: loss =  tensor([0.0963], grad_fn=<DivBackward0>)
# 4000: loss =  tensor([0.0120], grad_fn=<DivBackward0>)
# 4100: loss =  tensor([0.0024], grad_fn=<DivBackward0>)
# 4200: loss =  tensor([0.0079], grad_fn=<DivBackward0>)
# 4300: loss =  tensor([0.0038], grad_fn=<DivBackward0>)
# 4400: loss =  tensor([0.0055], grad_fn=<DivBackward0>)
# 4500: loss =  tensor([0.0112], grad_fn=<DivBackward0>)
# 4600: loss =  tensor([0.0007], grad_fn=<DivBackward0>)
# 4700: loss =  tensor([0.0009], grad_fn=<DivBackward0>)
# 4800: loss =  tensor([0.0018], grad_fn=<DivBackward0>)
# 4900: loss =  tensor([0.0064], grad_fn=<DivBackward0>)
# 5000: loss =  tensor([0.0010], grad_fn=<DivBackward0>)
# 5100: loss =  tensor([0.0009], grad_fn=<DivBackward0>)
# 5200: loss =  tensor([0.0150], grad_fn=<DivBackward0>)
# 5300: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 5400: loss =  tensor([0.0104], grad_fn=<DivBackward0>)
# 5500: loss =  tensor([0.0014], grad_fn=<DivBackward0>)
# 5600: loss =  tensor([0.0039], grad_fn=<DivBackward0>)
# 5700: loss =  tensor([0.0058], grad_fn=<DivBackward0>)
# 5800: loss =  tensor([0.0020], grad_fn=<DivBackward0>)
# 5900: loss =  tensor([0.0038], grad_fn=<DivBackward0>)
# 6000: loss =  tensor([0.0028], grad_fn=<DivBackward0>)
# 6100: loss =  tensor([0.2418], grad_fn=<DivBackward0>)
# 6200: loss =  tensor([0.0087], grad_fn=<DivBackward0>)
# 6300: loss =  tensor([0.0020], grad_fn=<DivBackward0>)
# 6400: loss =  tensor([0.0006], grad_fn=<DivBackward0>)
# 6500: loss =  tensor([0.0066], grad_fn=<DivBackward0>)
# 6600: loss =  tensor([0.0031], grad_fn=<DivBackward0>)
# 6700: loss =  tensor([0.0047], grad_fn=<DivBackward0>)
# 6800: loss =  tensor([0.0070], grad_fn=<DivBackward0>)
# 6900: loss =  tensor([0.0014], grad_fn=<DivBackward0>)
# 7000: loss =  tensor([0.0401], grad_fn=<DivBackward0>)
# 7100: loss =  tensor([0.0045], grad_fn=<DivBackward0>)
# 7200: loss =  tensor([0.0538], grad_fn=<DivBackward0>)
# 7300: loss =  tensor([0.0027], grad_fn=<DivBackward0>)
# 7400: loss =  tensor([0.0009], grad_fn=<DivBackward0>)
# 7500: loss =  tensor([0.0995], grad_fn=<DivBackward0>)
# 7600: loss =  tensor([0.0042], grad_fn=<DivBackward0>)
# 7700: loss =  tensor([0.0057], grad_fn=<DivBackward0>)
# 7800: loss =  tensor([0.0014], grad_fn=<DivBackward0>)
# 7900: loss =  tensor([0.0040], grad_fn=<DivBackward0>)
# 8000: loss =  tensor([0.0059], grad_fn=<DivBackward0>)
# 8100: loss =  tensor([0.0126], grad_fn=<DivBackward0>)
# 8200: loss =  tensor([0.0014], grad_fn=<DivBackward0>)
# 8300: loss =  tensor([0.0022], grad_fn=<DivBackward0>)
# 8400: loss =  tensor([0.0014], grad_fn=<DivBackward0>)
# 8500: loss =  tensor([0.0006], grad_fn=<DivBackward0>)
# 8600: loss =  tensor([0.0007], grad_fn=<DivBackward0>)
# 8700: loss =  tensor([0.0041], grad_fn=<DivBackward0>)
# 8800: loss =  tensor([0.0007], grad_fn=<DivBackward0>)
# 8900: loss =  tensor([0.0031], grad_fn=<DivBackward0>)
# 9000: loss =  tensor([0.0158], grad_fn=<DivBackward0>)
# 9100: loss =  tensor([0.0011], grad_fn=<DivBackward0>)
# 9200: loss =  tensor([0.0167], grad_fn=<DivBackward0>)
# 9300: loss =  tensor([0.0038], grad_fn=<DivBackward0>)
# 9400: loss =  tensor([0.0075], grad_fn=<DivBackward0>)
# 9500: loss =  tensor([0.0004], grad_fn=<DivBackward0>)
# 9600: loss =  tensor([0.0078], grad_fn=<DivBackward0>)
# 9700: loss =  tensor([0.0007], grad_fn=<DivBackward0>)
# 9800: loss =  tensor([0.0026], grad_fn=<DivBackward0>)
# 9900: loss =  tensor([0.0013], grad_fn=<DivBackward0>)
# Text(0.5, 0, 'Epoch')

# %%
plt.figure(figsize=FIGSIZE)
plt.semilogy(epoch_arr_tot_tanh, loss_arr_tot_tanh)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.savefig(FIGPATH+"PDE_TANH_LOSS.pdf")

# %%
plot_pde(model=model_tanh, grid_size=11, fn="PDE_TANH_10x10")
plot_pde(model=model_tanh, grid_size=100, fn="PDE_TANH_100x100")
plot_error(model_tanh, np.linspace(0,1, 200), np.linspace(0,1,200), fn="PDE_TANH_ERR")
# Out:
# <ipython-input-45-c83bb75c3924>:41: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cf = ax.pcolormesh(x, t, g, cmap=plt.get_cmap("jet"))
# <ipython-input-45-c83bb75c3924>:78: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   cf = ax.pcolormesh(x, t, relative_error, cmap=plt.get_cmap("jet"),label="MSE")
